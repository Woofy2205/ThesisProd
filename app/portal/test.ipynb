# %%
from pathlib import Path
import os

# %%
# chose the parent directory
cwd = os.getcwd()
parent = Path(cwd).parent.parent

# %%
cwd
# Out:
# 'c:\\Users\\Learning\\Project\\ThesisProd\\app\\portal'

# %%
parent
# Out:
# WindowsPath('c:/Users/Learning/Project/ThesisProd')

# %%
app = Path(parent).joinpath('app')
