# %%
cd ..
# Out:
# d:\Project\ThesisProd

# %%
from core.ingestion.preprocessing.audio.AudioProcessing import AudioProcessor

# %%
video = "https://www.youtube.com/watch?v=PeMlggyqz0Y"

# %%
new = AudioProcessor(audio_path = video)
# Out:
# Loaded audio file https://www.youtube.com/watch?v=PeMlggyqz0Y.

# %%
vid_title = new.process_download(video_url=video)
# Out:
# https://www.youtube.com/watch?v=PeMlggyqz0Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PeMlggyqz0Y
# [youtube] PeMlggyqz0Y: Downloading webpage
# [youtube] PeMlggyqz0Y: Downloading tv client config
# [youtube] PeMlggyqz0Y: Downloading player 5ae7d525
# [youtube] PeMlggyqz0Y: Downloading tv player API JSON
# [youtube] PeMlggyqz0Y: Downloading ios player API JSON
# [youtube] PeMlggyqz0Y: Downloading m3u8 information
# WARNING: [youtube] Failed to download m3u8 information: <urllib3.connection.HTTPSConnection object at 0x000002E535A3CCB0>: Failed to resolve 'manifest.googlevideo.com' ([Errno 11001] getaddrinfo failed)
# [info] PeMlggyqz0Y: Downloading 1 format(s): 18
# [download] Destination: d:\Project\ThesisProdstatic\speechdir\audio_cont\Machine Learning Explained in 100 Seconds.mp4
# [download] 100% of    3.99MiB in 00:00:00 at 7.90MiB/s
